# %%
import statsmodels.api as sm
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('LabTAT.csv')
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
df.mean()
# Out:
# Laboratory 1    178.361583
# Laboratory 2    178.902917
# Laboratory 3    199.913250
# Laboratory 4    163.682750
# dtype: float64

# %%
df.std()
# Out:
# Laboratory 1    13.173594
# Laboratory 2    14.957114
# Laboratory 3    16.539033
# Laboratory 4    15.085080
# dtype: float64

# %%
stats.f_oneway(df.iloc[:,0], df.iloc[:,1],df.iloc[:,2],df.iloc[:,3],)
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
## We can also plot the histogram of the data 
## to check if it approximately follows a Normal distribution.
plt.figure(figsize=(7,4))
plt.title("Laboratory 1",fontsize=16)
sns.distplot(df["Laboratory 1"].dropna(),color='pink',bins=25)
plt.show()

# %%
## we can also plot the histogram of the data
## to check if it approximately follows a Normal distribution.
plt.figure(figsize=(7,4))
plt.title("Laboratory 2",fontsize=16)
sns.distplot(df["Laboratory 2"].dropna(),color='green',bins=25)
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("Laboratory 3",fontsize=16)
sns.distplot(df["Laboratory 3"].dropna(),color='pink',bins=25)
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("Laboratory 4",fontsize=16)
sns.distplot(df["Laboratory 4"].dropna(),color='green',bins=25)
plt.show()
