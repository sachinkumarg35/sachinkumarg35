# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#!pip install mlxtend

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
#items = []
#with open("toy_dataset.csv") as f:
#    items = f.read()

# %%
items = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
items
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
# splitting the data into separate transactions using separator as "\n"
#items = items.split("\n")
#items_list = []
#for i in items:
#    items_list.append(i.split(","))

# %%
items_list=items

# %%
#items_list

# %%
te = TransactionEncoder()
te_ary = te.fit(items_list).transform(items_list)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
#apriori(df, min_support=0.4, use_colnames=True)

# %%
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                                     itemsets  length
# 0       0.4                                       (Corn)       1
# 1       0.8                                       (Eggs)       1
# 2       1.0                               (Kidney Beans)       1
# 3       0.6                                       (Milk)       1
# 4       0.4                                     (Nutmeg)       1
# 5       0.6                                      (Onion)       1
# 6       0.6                                     (Yogurt)       1
# 7       0.4                         (Corn, Kidney Beans)       2
# 8       0.8                         (Eggs, Kidney Beans)       2
# 9       0.4                                 (Eggs, Milk)       2
# 10      0.4                               (Eggs, Nutmeg)       2
# 11      0.6                                (Eggs, Onion)       2
# 12      0.4                               (Eggs, Yogurt)       2
# 13      0.6                         (Milk, Kidney Beans)       2
# 14      0.4                       (Nutmeg, Kidney Beans)       2
# 15      0.6                        (Onion, Kidney Beans)       2
# 16      0.6                       (Yogurt, Kidney Beans)       2
# 17      0.4                               (Milk, Yogurt)       2
# 18      0.4                              (Onion, Nutmeg)       2
# 19      0.4                             (Yogurt, Nutmeg)       2
# 20      0.4                              (Yogurt, Onion)       2
# 21      0.4                   (Eggs, Milk, Kidney Beans)       3
# 22      0.4                 (Eggs, Nutmeg, Kidney Beans)       3
# 23      0.6                  (Eggs, Onion, Kidney Beans)       3
# 24      0.4                 (Eggs, Yogurt, Kidney Beans)       3
# 25      0.4                        (Eggs, Onion, Nutmeg)       3
# 26      0.4                       (Eggs, Yogurt, Nutmeg)       3
# 27      0.4                        (Eggs, Yogurt, Onion)       3
# 28      0.4                 (Milk, Yogurt, Kidney Beans)       3
# 29      0.4                (Onion, Nutmeg, Kidney Beans)       3
# 30      0.4               (Yogurt, Nutmeg, Kidney Beans)       3
# 31      0.4                (Yogurt, Onion, Kidney Beans)       3
# 32      0.4                      (Yogurt, Onion, Nutmeg)       3
# 33      0.4          (Eggs, Onion, Nutmeg, Kidney Beans)       4
# 34      0.4         (Eggs, Yogurt, Nutmeg, Kidney Beans)       4
# 35      0.4          (Eggs, Yogurt, Onion, Kidney Beans)       4
# 36      0.4                (Eggs, Yogurt, Onion, Nutmeg)       4
# 37      0.4        (Yogurt, Onion, Nutmeg, Kidney Beans)       4
# 38      0.4  (Onion, Kidney Beans, Yogurt, Eggs, Nutmeg)       5

# %%
#frequent_itemsets[ (frequent_itemsets['length'] == 2) &
#                   (frequent_itemsets['support'] >= 0.5) ]

# %%
rules = association_rules(frequent_itemsets,  min_threshold=1)
rules.head()
# Out:
#   antecedents     consequents  antecedent support  consequent support  \
# 0      (Corn)  (Kidney Beans)                 0.4                 1.0
# 1      (Eggs)  (Kidney Beans)                 0.8                 1.0
# 2    (Nutmeg)          (Eggs)                 0.4                 0.8
# 3     (Onion)          (Eggs)                 0.6                 0.8
# 4      (Milk)  (Kidney Beans)                 0.6                 1.0
#
#    support  confidence  lift  leverage  conviction
# 0      0.4         1.0  1.00      0.00         inf
# 1      0.8         1.0  1.00      0.00         inf
# 2      0.4         1.0  1.25      0.08         inf
# 3      0.6         1.0  1.25      0.12         inf
# 4      0.6         1.0  1.00      0.00         inf

# %%
rules[ (rules['lift'] >= 2.5) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                             antecedents                          consequents  \
# 21                       (Eggs, Yogurt)                             (Nutmeg)
# 24                             (Nutmeg)                       (Eggs, Yogurt)
# 35                      (Yogurt, Onion)                             (Nutmeg)
# 38                             (Nutmeg)                      (Yogurt, Onion)
# 47         (Eggs, Yogurt, Kidney Beans)                             (Nutmeg)
# 50                       (Eggs, Yogurt)               (Kidney Beans, Nutmeg)
# 53               (Kidney Beans, Nutmeg)                       (Eggs, Yogurt)
# 54                             (Nutmeg)         (Eggs, Yogurt, Kidney Beans)
# 60                (Eggs, Yogurt, Onion)                             (Nutmeg)
# 64                       (Eggs, Yogurt)                      (Onion, Nutmeg)
# 65                       (Eggs, Nutmeg)                      (Yogurt, Onion)
# 66                      (Yogurt, Onion)                       (Eggs, Nutmeg)
# 68                      (Onion, Nutmeg)                       (Eggs, Yogurt)
# 69                             (Nutmeg)                (Eggs, Yogurt, Onion)
# 71        (Yogurt, Onion, Kidney Beans)                             (Nutmeg)
# 74                      (Yogurt, Onion)               (Kidney Beans, Nutmeg)
# 77               (Kidney Beans, Nutmeg)                      (Yogurt, Onion)
# 78                             (Nutmeg)        (Yogurt, Onion, Kidney Beans)
# 79  (Eggs, Yogurt, Onion, Kidney Beans)                             (Nutmeg)
# 84        (Yogurt, Onion, Kidney Beans)                       (Eggs, Nutmeg)
# 85        (Onion, Nutmeg, Kidney Beans)                       (Eggs, Yogurt)
# 86                (Eggs, Yogurt, Onion)               (Nutmeg, Kidney Beans)
# 89         (Eggs, Yogurt, Kidney Beans)                      (Onion, Nutmeg)
# 91         (Eggs, Nutmeg, Kidney Beans)                      (Yogurt, Onion)
# 93                      (Yogurt, Onion)         (Eggs, Nutmeg, Kidney Beans)
# 94                      (Onion, Nutmeg)         (Eggs, Yogurt, Kidney Beans)
# 95               (Nutmeg, Kidney Beans)                (Eggs, Yogurt, Onion)
# 96                       (Eggs, Yogurt)        (Onion, Nutmeg, Kidney Beans)
# 98                       (Eggs, Nutmeg)        (Yogurt, Onion, Kidney Beans)
# 99                             (Nutmeg)  (Eggs, Yogurt, Onion, Kidney Beans)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 21                 0.4                 0.4      0.4         1.0   2.5
# 24                 0.4                 0.4      0.4         1.0   2.5
# 35                 0.4                 0.4      0.4         1.0   2.5
# 38                 0.4                 0.4      0.4         1.0   2.5
# 47                 0.4                 0.4      0.4         1.0   2.5
# 50                 0.4                 0.4      0.4         1.0   2.5
# 53                 0.4                 0.4      0.4         1.0   2.5
# 54                 0.4                 0.4      0.4         1.0   2.5
# 60                 0.4                 0.4      0.4         1.0   2.5
# 64                 0.4                 0.4      0.4         1.0   2.5
# 65                 0.4                 0.4      0.4         1.0   2.5
# 66                 0.4                 0.4      0.4         1.0   2.5
# 68                 0.4                 0.4      0.4         1.0   2.5
# 69                 0.4                 0.4      0.4         1.0   2.5
# 71                 0.4                 0.4      0.4         1.0   2.5
# 74                 0.4                 0.4      0.4         1.0   2.5
# 77                 0.4                 0.4      0.4         1.0   2.5
# 78                 0.4                 0.4      0.4         1.0   2.5
# 79                 0.4                 0.4      0.4         1.0   2.5
# 84                 0.4                 0.4      0.4         1.0   2.5
# 85                 0.4                 0.4      0.4         1.0   2.5
# 86                 0.4                 0.4      0.4         1.0   2.5
# 89                 0.4                 0.4      0.4         1.0   2.5
# 91                 0.4                 0.4      0.4         1.0   2.5
# 93                 0.4                 0.4      0.4         1.0   2.5
# 94                 0.4                 0.4      0.4         1.0   2.5
# 95                 0.4                 0.4      0.4         1.0   2.5
# 96                 0.4                 0.4      0.4         1.0   2.5
# 98                 0.4                 0.4      0.4         1.0   2.5
# 99                 0.4                 0.4      0.4         1.0   2.5
#
#     leverage  conviction
# 21      0.24         inf
# 24      0.24         inf
# 35      0.24         inf
# 38      0.24         inf
# 47      0.24         inf
# 50      0.24         inf
# 53      0.24         inf
# 54      0.24         inf
# 60      0.24         inf
# 64      0.24         inf
# 65      0.24         inf
# 66      0.24         inf
# 68      0.24         inf
# 69      0.24         inf
# 71      0.24         inf
# 74      0.24         inf
# 77      0.24         inf
# 78      0.24         inf
# 79      0.24         inf
# 84      0.24         inf
# 85      0.24         inf
# 86      0.24         inf
# 89      0.24         inf
# 91      0.24         inf
# 93      0.24         inf
# 94      0.24         inf
# 95      0.24         inf
# 96      0.24         inf
# 98      0.24         inf
# 99      0.24         inf
